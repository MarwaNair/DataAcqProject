# %%
import pandas as pd

# %%
# Load the CSV file
# df = pd.read_csv('francetravail_job_listings.csv', encoding='utf-8')
df = pd.read_csv('adzuna_job_listings.csv', encoding='utf-8')

# %%
# Print the first few rows
df.tail(10)
# Out:
#                                                  title  \
# 190            Consultant Responsible AI Advisor (F/H)
# 191     AI/ML Data Scientist Détails du poste | ERAMET
# 192                  Research Intern, Privacy in AI/ML
# 193            Consultant Responsible AI Advisor (F/H)
# 194           Stage:- AI for Data Products marketplace
# 195                        AI Project Manager F/H  CDI
# 196  CONVERSATIONNEL || AI Trainer || Alternance/St...
# 197         Sales Specialist (Gen AI & Creative Cloud)
# 198                       Lead Data Science & AI (H/F)
# 199         Internship - Applied AI for Cyber Security
#
#                           company                     location  \
# 190              Accenture France  13ème Arrondissement, Paris
# 191                        Eramet         Paris, Ile-de-France
# 192                           L05                       France
# 193                     Accenture         Paris, Ile-de-France
# ...

# %%
# Display summary statistics
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            200 non-null    object
#  1   company          200 non-null    object
#  2   location         200 non-null    object
#  3   description      200 non-null    object
#  4   employment_type  37 non-null     object
#  5   contract_type    55 non-null     object
#  6   date_posted      200 non-null    object
#  7   job_url          200 non-null    object
# dtypes: object(8)
# memory usage: 12.6+ KB

# %%
for col in df.columns[4:6]:
  print(df[col].unique())
# Out:
# ['permanent' nan 'contract']
# [nan 'full_time' 'part_time']
